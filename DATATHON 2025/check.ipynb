# %%
import pandas as pd

final = pd.read_csv("combined_dataset_labels.csv")
final
# Out:
#                                              image_file  \
# 0     2702301400041269896_jpg.rf.a3e7d216f9568d65414...
# 1     2776541157006847667_jpg.rf.a3b02e3fd7bd20ebdda...
# 2     IMG_0221_JPG_jpg.rf.a2cd9012a9829754be4ffc5db7...
# 3     IMG_20180723_145651_jpg.rf.a3bfe0dddf3ab390421...
# 4     IMG_20180723_144902_jpg.rf.a38fc97e2c5be529897...
# ...                                                 ...
# 6684  IMG_8949_jpg.rf.94b4d23462573a791990cf7619086b...
# 6685  IMG_8985_jpg.rf.9de6c68aab71cdb2993d5afed478ba...
# 6686  Capture_JPG_jpg.rf.4a50199210b18c0783f3d610407...
# 6687  IMG_8906_jpg.rf.876037d1fd35c436c22c7028d0d4ec...
# 6688  IMG_8734_jpg.rf.6331cc835bf1433b2ad7c87d5446b9...
#
#                                     main_category               sub_category  \
# 0     Public Cleanliness & Public Property Damage                  Vandalism
# 1     Public Cleanliness & Public Property Damage                  Vandalism
# ...
